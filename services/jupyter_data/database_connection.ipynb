# %%
import pyodbc
import dataset

# %%
username = 'sa'
password = 'SqlServer2019!'
database = 'master'

# Define the connection string for your SQL Server database
# Replace 'your_username', 'your_password', 'your_database' with your actual credentials
connection_string = f'mssql+pyodbc://{username}:{password}@127.0.0.1:1433/{database}?driver=ODBC+Driver+17+for+SQL+Server'

## SERVER=xxxTest-SRV,51333;
# Connect to the SQL Server database
db = dataset.connect(connection_string)

# %%
print(db.tables)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/engine/base.py:3371, in Engine._wrap_pool_connect(self, fn, connection)
#    3370 try:
# -> 3371     return fn()
#    3372 except dialect.dbapi.Error as e:
#
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# ...

# %%
# Example: Read data from a table named 'orders'
table = db['production.products']

# Example: Fetch a limited number of records
limited_rows = table.all(limit=5)
for row in limited_rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/engine/base.py:3371, in Engine._wrap_pool_connect(self, fn, connection)
#    3370 try:
# -> 3371     return fn()
#    3372 except dialect.dbapi.Error as e:
#
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# ...
